# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
ThisDir = "C3d_ThreePointIntSync" #CHANGE THIS BY HAND!!!

SolDir  = "{}_sol".format(ThisDir)

OrdParamDir  = "{}_r".format(ThisDir)

PlotDir  = "{}_Plots".format(ThisDir)
if not os.path.exists(PlotDir): os.makedirs(PlotDir)

# %%
K1_List = np.linspace(-2.0, 2.0, 21)
K2_List = np.linspace(0.0, 2.0, 21)

# %%
ic_omega = 0
ic_theta = 8
#---------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
for kk2 in range(21):
    K2 = K2_List[kk2]
    #----------------------------------------
    r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
    r_df = pd.read_csv(r_FileName)
    #----------------------------------------

    ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
                fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

    ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
    ax.grid(True)

    ax.set_ylabel("Order Parameter, r", fontsize=15)
    ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
#     ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

    # FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
    # plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 0
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

# FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
# plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 1
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 2
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 3
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 4
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 5
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 6
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 7
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 8
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 9
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 10
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 11
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 12
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 13
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 14
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 15
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# Time:
t_start = 0
t_stop = 500
dt = 0.01

t_List = np.arange(t_start, t_stop, dt)

N_t = len(t_List)
#----------------------------------------
# Length of end part of order parameter TS on which time avg will be calculated:
N_r = int((2./5)*N_t)
print("N_t = {}".format(N_t))
print("N_r = {}".format(N_r))
print("#----------------------------------------")
# print("\n")

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 0
K2 = K2_List[kk2]
#----------------------------------------

# %%
# %%time

r_List = []
r_std_List = []

for kk1, K1 in enumerate(K1_List[:14]):
    sol_FileName_npy = f"{SolDir}/{ThisDir}_sol_omega{ic_omega}_theta{ic_theta}_K1_{kk1}_K2_{kk2}.npy"
    sol = np.load(sol_FileName_npy)
    #----------------------------------------
    # Put solution in pandas df:
    sol_dict = {}
    for osc_index, node in enumerate(NodeList):
        sol_dict["osc"+node] = sol[:,osc_index]
    sol_df =  pd.DataFrame.from_dict(sol_dict, dtype=np.float64)
    sol_df = sol_df%(2*np.pi)
    #----------------------------------------
    # Calculate order parameter:
    x_pos_df = np.cos(sol_df)
    y_pos_df = np.sin(sol_df)
    #---
    r_x_df = x_pos_df.sum(axis=1)/N
    r_y_df = y_pos_df.sum(axis=1)/N

    r_df = np.sqrt(r_x_df**2 + r_y_df**2)
    #----------------------------------------
    r_ForCalc = r_df.values[-N_r:]

    r_TimeAvg = np.mean(r_ForCalc)
    r_std = np.std(r_ForCalc, ddof=1)
    #r_std_error = r_std/np.sqrt(N_r)
    #r_MaxMin = max(r_ForCalc) - min(r_ForCalc)
    
    r_List.append(r_TimeAvg)
    r_std_List.append(r_std)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(K1_List[:len(r_List)], r_List, r_std_List,
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8)

ax.set(xlim=(-4.1, -1.9), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

# ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K1_{kk1}.png"
# plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 0
K2 = K2_List[kk2]
#----------------------------------------
r_FileName = f"{OrdParamDir}/{ThisDir}_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df = pd.read_csv(r_FileName)
#---------------
# r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
# r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
# r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
# r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df["K1"], r_df["TimeAvg"], r_df["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="forward sweep")

# ax.errorbar(r_df_backward["K1"], r_df_backward["TimeAvg"], r_df_backward["StdDev"],
#             fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="backward sweep")

# # ax.errorbar(r_df_forward2["K1"], r_df_forward2["TimeAvg"], r_df_forward2["StdDev"],
# #             fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="2nd forward sweep")


# ax.errorbar(old_r_df_forward["K1"], old_r_df_forward["TimeAvg"], old_r_df_forward["StdDev"],
#             fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="old forward sweep")

# ax.errorbar(old_r_df_backward["K1"], old_r_df_backward["TimeAvg"], old_r_df_backward["StdDev"],
#             fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="old backward sweep")


# ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K1_{kk1}.png"
# plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 0
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
# r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
# r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.errorbar(r_df_forward["K1"], r_df_forward["TimeAvg"], r_df_forward["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="forward sweep")

ax.errorbar(r_df_backward["K1"], r_df_backward["TimeAvg"], r_df_backward["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="backward sweep")

# ax.errorbar(r_df_forward2["K1"], r_df_forward2["TimeAvg"], r_df_forward2["StdDev"],
#             fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="2nd forward sweep")


ax.errorbar(old_r_df_forward["K1"], old_r_df_forward["TimeAvg"], old_r_df_forward["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="old forward sweep")

ax.errorbar(old_r_df_backward["K1"], old_r_df_backward["TimeAvg"], old_r_df_backward["StdDev"],
            fmt='.-', fillstyle="none", capsize=5, alpha=0.8, label="old backward sweep")


ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"2-simplex coupling, $K_{2}$", fontsize=15)
ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K1_{kk1}.png"
# plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %%
r_FileName_forward

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 1
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 2
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 3
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 4
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 5
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 6
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 7
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 8
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 10
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 12
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 14
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 16
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()

# %% [markdown]
# ---

# %%
ic_omega = 0
ic_theta = 0
#---------------
kk2 = 18
K2 = K2_List[kk2]
#----------------------------------------
r_FileName_forward = f"{OrdParamDir}/{ThisDir}_forward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward = pd.read_csv(r_FileName_forward)
#---------------
r_FileName_backward = f"{OrdParamDir}/{ThisDir}_backward_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_backward = pd.read_csv(r_FileName_backward)
#---------------
r_FileName_forward2 = f"{OrdParamDir}/{ThisDir}_forward2_r_data_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.csv"
r_df_forward2 = pd.read_csv(r_FileName_forward2)
#----------------------------------------
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(r_df_forward["K1"], r_df_forward["TimeAvg"], "C0^-", label="forward sweep")
ax.plot(r_df_backward["K1"], r_df_backward["TimeAvg"], "C1v-", label="backward sweep")
ax.plot(r_df_forward2["K1"], r_df_forward2["TimeAvg"], "C2^-", label="2nd forward sweep")

ax.set(xlim=(-2.1, 2.1), ylim=(-0.1, 1.1))
ax.grid(True)

ax.set_ylabel("Order Parameter, r", fontsize=15)
ax.set_xlabel(r"1-simplex coupling, $K_{1}$", fontsize=15)

ax.set_title(rf"$K_{2}$={K2}, OmegaIC#{ic_omega}, ThetaIC#{ic_theta}", fontsize=15)

FigName = f"{PlotDir}/{ThisDir}_OrderParamVsTime_omega{ic_omega}_theta{ic_theta}_K2_{kk2}.png"
plt.savefig(FigName, format="png", transparent=False, bbox_inches="tight", pad_inches=0.1)

plt.show()
